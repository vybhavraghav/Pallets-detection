# %% [markdown]
# <a href="https://colab.research.google.com/github/vybhavraghav/Pallets-detection/blob/roboflow/src/Pallets_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/vybhavraghav/Pallets-detection.git
# Out:
# Cloning into 'Pallets-detection'...
# remote: Enumerating objects: 2505, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 2505 (delta 1), reused 48 (delta 1), pack-reused 2455 (from 1)
# Receiving objects: 100% (2505/2505), 159.55 MiB | 24.71 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# Updating files: 100% (2476/2476), done.

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.8/883.8 kB 35.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import torch
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !nvidia-smi
# Out:
# Tue Nov 12 06:08:53 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# %cd Pallets-detection/src
# Out:
# /content/Pallets-detection/src

# %%
seg_model = YOLO('yolo11n-seg.pt')

# %%
seg_results = seg_model.train(data="Dataset/data.yaml", epochs=50, imgsz=640)
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
seg_model.predict(source="Dataset/test/images", save=True)
# Out:
# image 1/160 /content/Pallets-detection/src/Dataset/test/images/1014902-4606_jpg.rf.debc08de8fcf1fbedf997fab7aaea934.jpg: 640x640 1 ground, 9 pallets, 23.2ms
# image 2/160 /content/Pallets-detection/src/Dataset/test/images/1041302-2676_jpg.rf.461639025dff361569a337ec1ddc6540.jpg: 640x640 1 ground, 9 pallets, 19.0ms
# image 3/160 /content/Pallets-detection/src/Dataset/test/images/1111168-8003_jpg.rf.62d7605e0442efb5ae5608a75565c9ad.jpg: 640x640 1 ground, 4 pallets, 16.0ms
# image 4/160 /content/Pallets-detection/src/Dataset/test/images/1210335-2054_jpg.rf.f6ab2b8c05d34867009b3f0cc1e67946.jpg: 640x640 1 ground, 3 pallets, 16.0ms
# image 5/160 /content/Pallets-detection/src/Dataset/test/images/1564562462-5886269_jpg.rf.ad6f039d77a05f41be3759ac60ab86e9.jpg: 640x640 1 ground, 19.1ms
# image 6/160 /content/Pallets-detection/src/Dataset/test/images/1564562504-1886058_jpg.rf.d4894f04d2cfc3caf67c4684eeb2659f.jpg: 640x640 1 ground, 6 pallets, 17.0ms
# ...
